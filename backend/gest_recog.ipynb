# %% [markdown]
# # **Importing Libraries**

# %%
# Import the needed Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
from imageio import imread
from skimage.transform import resize
import datetime
import os

# Supress all the warnings
import warnings
warnings.filterwarnings('ignore')

# Import the random seed and tensorflow
np.random.seed(30)
import random as rn
rn.seed(30)
import tensorflow as tf
tf.random.set_seed(30)
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, Flatten, TimeDistributed, BatchNormalization, Activation, Dropout, SimpleRNN, Conv2D, MaxPooling2D
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras import optimizers
# Out:
# WARNING:tensorflow:From c:\Users\Rahul\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %% [markdown]
# # **Loading the Data**

# %% [markdown]
# > In this process, this where we learn what's the dataset in consists of as well forming it into dimensions.

# %%
project_folder=r'C:\Users\Rahul\Desktop\Thumbs_up_and_down_Dataset'
read = pd.read_csv(r"C:\Users\Rahul\Desktop\Thumbs_up_and_down_Dataset\train.csv", dtype=object)
print(read.shape)
print(read.info())
# Out:
# (662, 1)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 662 entries, 0 to 661
# Data columns (total 1 columns):
#  #   Column                                                     Non-Null Count  Dtype
# ---  ------                                                     --------------  -----
#  0   WIN_20180925_17_08_43_Pro_Left_Swipe_new;Left_Swipe_new;0  662 non-null    object
# dtypes: object(1)
# memory usage: 5.3+ KB
# None

# %% [markdown]
# # **Generator**

# %% [markdown]
# > For train_doc and val_doc, it takes random lists of files in train.csv and val.csv to for when training CNN+RNN model.

# %%
## Let us take the Input in to Train and Val doc and Iniatise the Bath size as 10 first and then we train the model
train_doc = np.random.permutation(open(r"C:\Users\Rahul\Desktop\Thumbs_up_and_down_Dataset\train.csv").readlines())
val_doc = np.random.permutation(open(r"C:\Users\Rahul\Desktop\Thumbs_up_and_down_Dataset\val.csv").readlines())
batch_size = 10 #experiment with the batch size

# %% [markdown]
# > In this generator function below,there's  a dataset full of videos. The goal is to try to feed the batches of images from videos. What the function is essentially trying to do is ,from each video , to take x amount of images. For each images, they will be resize to the the number we initialize y and z. Then the images are stored inside the batch size (file). From this batch, each images are double checked if each one of them are in the same dimensions. If not, neural network will consider as an input error. If the two images are in different dimensions, the function will crop and resize the images. Once the whole process is done, the images are stored in another file to use for training the model.

# %%
# Let we do the generators and input the images as we see that our images have two different sizes. 

channels = 3 # RGB as 3D Convlution
clases = 5
x = 30 # No. of frames images
y = 120 # Width of the image
z = 120  # height

def generator_1(source_path, folder_list, batch_size):
    print( 'Source path = ', source_path, '; batch size =', batch_size)
    img_idx = [x for x in range(0,x)] #create a list of image numbers you want to use for a particular video
    while True:
        t = np.random.permutation(folder_list)
        num_batches = len(folder_list)//batch_size # calculate the number of batches
        for batch in range(num_batches): # we iterate over the number of batches
            batch_data = np.zeros((batch_size,x,y,z,channels)) # x is the number of images you use for each video, (y,z) is the final size of the input images and 3 is the number of channels RGB
            batch_labels = np.zeros((batch_size,clases)) # batch_labels is the one hot representation of the output
            for folder in range(batch_size): # iterate over the batch_size
                imgs = os.listdir(source_path+'/'+ t[folder + (batch*batch_size)].split(';')[0]) # read all the images in the folder
                for idx,item in enumerate(img_idx): #  Iterate iver the frames/images of a folder to read them in
                    image = imread(source_path+'/'+ t[folder + (batch*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)
                    
                    #crop the images and resize them. Note that the images are of 2 different shape 
                    #and the conv3D will throw error if the inputs in a batch have different shapes
                    # Let us resize all the images 
                    Temp_img = resize(image,(y,z)) 
                    Temp_img = Temp_img.mean(axis=-1,keepdims=1)  # Let us convert to the Grey scale
                    Temp_img = Temp_img/127.5-1 
                    
                    batch_data[folder,idx] = Temp_img #normalise and feed in the image
                    
                batch_labels[folder, int(t[folder + (batch*batch_size)].strip().split(';')[2])] = 1
            yield batch_data, batch_labels #you yield the batch_data and the batch_labels, remember what does yield do

 # write the code for the remaining data points which are left after full batches.
        
# Let us see that if the folder is not equal to the batch size * num of batches
        
        if (len(folder_list) != batch_size*num_batches):
            print("Batches: ",num_batches+1,"Index:", batch_size)
            batch_size = len(folder_list) - (batch_size*num_batches)
            batch_data = np.zeros((batch_size,x,y,z,channels)) # x is the number of images you use for each video, (y,z) is the final size of the input images and 3 is the number of channels RGB
            batch_labels = np.zeros((batch_size,clases)) # batch_labels is the one hot representation of the output
            for folder in range(batch_size): # iterate over the batch_size
                imgs = os.listdir(source_path+'/'+ t[folder + (batch*batch_size)].split(';')[0]) # read all the images in the folder
                for idx,item in enumerate(img_idx): #  Iterate iver the frames/images of a folder to read them in
                    image = imread(source_path+'/'+ t[folder + (batch*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)
                    
                    #crop the images and resize them. Note that the images are of 2 different shape 
                    #and the conv3D will throw error if the inputs in a batch have different shapes
                    Temp_img = resize(image,(y,z))
                    Temp_img = Temp_img.mean(axis=-1,keepdims=1)  # Let us convert to the Grey scale 
                    Temp_img = Temp_img/127.5-1 #Normalize data
                    
                    batch_data[folder,idx] = Temp_img
                   
                batch_labels[folder, int(t[folder + (batch*batch_size)].strip().split(';')[2])] = 1
            yield batch_data, batch_labels

# %% [markdown]
# > This function below is try to count how many videos are currently in train.csv and how many are in in val.csv.

# %%
curr_dt_time = datetime.datetime.now()
train_path = r"C:\Users\Rahul\Desktop\Thumbs_up_and_down_Dataset\Train"
val_path = r"C:\Users\Rahul\Desktop\Thumbs_up_and_down_Dataset\Val"
num_train_sequences = len(train_doc)
print('# Training_Sequences =', num_train_sequences)
num_val_sequences = len(val_doc)
print('# Validation_Sequences =', num_val_sequences)
num_epochs = 40 # choose the number of epochs
print ('# Epochs = ', num_epochs)
# Out:
# # Training_Sequences = 663
# # Validation_Sequences = 100
# # Epochs =  40

# %% [markdown]
# # **Building CNN+RNN Model**

# %%
CNNRNN_Model = Sequential()   

CNNRNN_Model.add(TimeDistributed(Conv2D(16, (3, 3) , padding='same', activation='relu'),input_shape=(x,y,z,3)))
CNNRNN_Model.add(TimeDistributed(BatchNormalization()))
CNNRNN_Model.add(TimeDistributed(MaxPooling2D((2, 2))))
        
CNNRNN_Model.add(TimeDistributed(Conv2D(32, (3, 3) , padding='same', activation='relu')))
CNNRNN_Model.add(TimeDistributed(BatchNormalization()))
CNNRNN_Model.add(TimeDistributed(MaxPooling2D((2, 2))))
        
CNNRNN_Model.add(TimeDistributed(Conv2D(64, (3, 3) , padding='same', activation='relu')))
CNNRNN_Model.add(TimeDistributed(BatchNormalization()))
CNNRNN_Model.add(TimeDistributed(MaxPooling2D((2, 2))))
        
CNNRNN_Model.add(TimeDistributed(Conv2D(128, (3, 3) , padding='same', activation='relu')))
CNNRNN_Model.add(TimeDistributed(BatchNormalization()))
CNNRNN_Model.add(TimeDistributed(MaxPooling2D((2, 2))))

# Flatten layer 

CNNRNN_Model.add(TimeDistributed(Flatten()))
CNNRNN_Model.add(SimpleRNN(64))
CNNRNN_Model.add(Dropout(0.25))

# Dense layer 
CNNRNN_Model.add(Dense(64,activation='relu'))
CNNRNN_Model.add(Dropout(0.25))
# Softmax layer

CNNRNN_Model.add(Dense(5, activation='softmax'))

# Adam optimiser

optimiser = optimizers.Adam(lr=0.01) #write your optimizer
CNNRNN_Model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
print (CNNRNN_Model.summary())
# Out:
# WARNING:tensorflow:From c:\Users\Rahul\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From c:\Users\Rahul\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\normalization\batch_normalization.py:979: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  time_distributed (TimeDist  (None, 30, 120, 120, 16   448
#  ributed)                    )
#
#  time_distributed_1 (TimeDi  (None, 30, 120, 120, 16   64
#  stributed)                  )
#
#  time_distributed_2 (TimeDi  (None, 30, 60, 60, 16)    0
#  stributed)
#
#  time_distributed_3 (TimeDi  (None, 30, 60, 60, 32)    4640
#  stributed)
#
#  time_distributed_4 (TimeDi  (None, 30, 60, 60, 32)    128
#  stributed)
#
#  time_distributed_5 (TimeDi  (None, 30, 30, 30, 32)    0
#  stributed)
#
#  time_distributed_6 (TimeDi  (None, 30, 30, 30, 64)    18496
#  stributed)
#
#  time_distributed_7 (TimeDi  (None, 30, 30, 30, 64)    256
#  stributed)
#
#  time_distributed_8 (TimeDi  (None, 30, 15, 15, 64)    0
#  stributed)
#
#  time_distributed_9 (TimeDi  (None, 30, 15, 15, 128)   73856
#  stributed)
#
#  time_distributed_10 (TimeD  (None, 30, 15, 15, 128)   512
#  istributed)
#
#  time_distributed_11 (TimeD  (None, 30, 7, 7, 128)     0
#  istributed)
#
#  time_distributed_12 (TimeD  (None, 30, 6272)          0
#  istributed)
#
#  simple_rnn (SimpleRNN)      (None, 64)                405568
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense (Dense)               (None, 64)                4160
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_1 (Dense)             (None, 5)                 325
#
# =================================================================
# Total params: 508453 (1.94 MB)
# Trainable params: 507973 (1.94 MB)
# Non-trainable params: 480 (1.88 KB)
# _________________________________________________________________
# None

# %%
# Let us train and validate the model 
train_generator = generator_1(train_path, train_doc, batch_size)
val_generator = generator_1(val_path, val_doc, batch_size)

# %%
# Let us see the Validate the Losses and put back the checkpoint

model_name = 'model_init' + '_' + str(curr_dt_time).replace(' ','').replace(':','_') + '/'
    
if not os.path.exists(model_name):
    os.mkdir(model_name)
        
filepath = model_name + 'model-{epoch:05d}-{loss:.5f}-{categorical_accuracy:.5f}-{val_loss:.5f}-{val_categorical_accuracy:.5f}.h5'

checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=False, save_weights_only=False, mode='auto', period=1)

LR = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=2, cooldown=1, verbose=1) # write the REducelronplateau code here
callbacks_list = [checkpoint, LR]
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
# Let us see that the steps_per_epoch and validation steps are used by fit to decide the no. of next()

if (num_train_sequences%batch_size) == 0:
    steps_per_epoch = int(num_train_sequences/batch_size)
else:
    steps_per_epoch = (num_train_sequences//batch_size) + 1

if (num_val_sequences%batch_size) == 0:
    validation_steps = int(num_val_sequences/batch_size)
else:
    validation_steps = (num_val_sequences//batch_size) + 1

# %%
history = CNNRNN_Model.fit(train_generator, steps_per_epoch = steps_per_epoch, epochs=40, verbose=1,
                    callbacks=callbacks_list, validation_data=val_generator, 
                    validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# Source path =  C:\Users\Rahul\Desktop\Thumbs_up_and_down_Dataset\Train ; batch size = 10
# Epoch 1/40
# WARNING:tensorflow:From c:\Users\Rahul\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
# WARNING:tensorflow:From c:\Users\Rahul\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
# WARNING:tensorflow:From c:\Users\Rahul\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
# WARNING:tensorflow:From c:\Users\Rahul\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
# 65/67 [============================>.] - ETA: 3s - loss: 1.6639 - categorical_accuracy: 0.2677Batches:  67 Index: 10
# 67/67 [==============================] - ETA: 0s - loss: 1.6573 - categorical_accuracy: 0.2655Source path =  C:\Users\Rahul\Desktop\Thumbs_up_and_down_Dataset\Val ; batch size = 10
#
# Epoch 1: saving model to model_init_2024-01-2715_31_08.356252\model-00001-1.65727-0.26546-1.79093-0.19000.h5
# 67/67 [==============================] - 148s 2s/step - loss: 1.6573 - categorical_accuracy: 0.2655 - val_loss: 1.7909 - val_categorical_accuracy: 0.1900 - lr: 0.0010
# Epoch 2/40
# 67/67 [==============================] - ETA: 0s - loss: 1.5989 - categorical_accuracy: 0.2786
# Epoch 2: saving model to model_init_2024-01-2715_31_08.356252\model-00002-1.59890-0.27861-1.63324-0.30000.h5
# 67/67 [==============================] - 57s 864ms/step - loss: 1.5989 - categorical_accuracy: 0.2786 - val_loss: 1.6332 - val_categorical_accuracy: 0.3000 - lr: 0.0010
# Epoch 3/40
# 67/67 [==============================] - ETA: 0s - loss: 1.6956 - categorical_accuracy: 0.2587
# Epoch 3: saving model to model_init_2024-01-2715_31_08.356252\model-00003-1.69559-0.25871-1.62706-0.32000.h5
# 67/67 [==============================] - 57s 867ms/step - loss: 1.6956 - categorical_accuracy: 0.2587 - val_loss: 1.6271 - val_categorical_accuracy: 0.3200 - lr: 0.0010
# Epoch 4/40
# 67/67 [==============================] - ETA: 0s - loss: 1.5450 - categorical_accuracy: 0.3582
# Epoch 4: saving model to model_init_2024-01-2715_31_08.356252\model-00004-1.54500-0.35821-1.94941-0.23000.h5
# 67/67 [==============================] - 54s 822ms/step - loss: 1.5450 - categorical_accuracy: 0.3582 - val_loss: 1.9494 - val_categorical_accuracy: 0.2300 - lr: 0.0010
# Epoch 5/40
# 67/67 [==============================] - ETA: 0s - loss: 1.5296 - categorical_accuracy: 0.3134
# Epoch 5: saving model to model_init_2024-01-2715_31_08.356252\model-00005-1.52958-0.31343-1.55410-0.39000.h5
# 67/67 [==============================] - 52s 789ms/step - loss: 1.5296 - categorical_accuracy: 0.3134 - val_loss: 1.5541 - val_categorical_accuracy: 0.3900 - lr: 0.0010
# Epoch 6/40
# 67/67 [==============================] - ETA: 0s - loss: 1.5824 - categorical_accuracy: 0.3483
# Epoch 6: saving model to model_init_2024-01-2715_31_08.356252\model-00006-1.58239-0.34826-1.58805-0.36000.h5
# 67/67 [==============================] - 45s 675ms/step - loss: 1.5824 - categorical_accuracy: 0.3483 - val_loss: 1.5881 - val_categorical_accuracy: 0.3600 - lr: 0.0010
# Epoch 7/40
# 67/67 [==============================] - ETA: 0s - loss: 1.4714 - categorical_accuracy: 0.3632
# Epoch 7: saving model to model_init_2024-01-2715_31_08.356252\model-00007-1.47136-0.36318-1.40247-0.36000.h5
# 67/67 [==============================] - 65s 979ms/step - loss: 1.4714 - categorical_accuracy: 0.3632 - val_loss: 1.4025 - val_categorical_accuracy: 0.3600 - lr: 0.0010
# Epoch 8/40
# 67/67 [==============================] - ETA: 0s - loss: 1.4878 - categorical_accuracy: 0.3483
# Epoch 8: saving model to model_init_2024-01-2715_31_08.356252\model-00008-1.48780-0.34826-1.33572-0.41000.h5
# 67/67 [==============================] - 60s 913ms/step - loss: 1.4878 - categorical_accuracy: 0.3483 - val_loss: 1.3357 - val_categorical_accuracy: 0.4100 - lr: 0.0010
# Epoch 9/40
# 67/67 [==============================] - ETA: 0s - loss: 1.3969 - categorical_accuracy: 0.3930
# Epoch 9: saving model to model_init_2024-01-2715_31_08.356252\model-00009-1.39688-0.39303-1.30279-0.45000.h5
# 67/67 [==============================] - 66s 1s/step - loss: 1.3969 - categorical_accuracy: 0.3930 - val_loss: 1.3028 - val_categorical_accuracy: 0.4500 - lr: 0.0010
# Epoch 10/40
# 67/67 [==============================] - ETA: 0s - loss: 1.5022 - categorical_accuracy: 0.3483
# Epoch 10: saving model to model_init_2024-01-2715_31_08.356252\model-00010-1.50221-0.34826-1.22430-0.51000.h5
# 67/67 [==============================] - 66s 991ms/step - loss: 1.5022 - categorical_accuracy: 0.3483 - val_loss: 1.2243 - val_categorical_accuracy: 0.5100 - lr: 0.0010
# Epoch 11/40
# 67/67 [==============================] - ETA: 0s - loss: 1.5758 - categorical_accuracy: 0.3134
# Epoch 11: saving model to model_init_2024-01-2715_31_08.356252\model-00011-1.57577-0.31343-1.52108-0.32000.h5
# 67/67 [==============================] - 63s 952ms/step - loss: 1.5758 - categorical_accuracy: 0.3134 - val_loss: 1.5211 - val_categorical_accuracy: 0.3200 - lr: 0.0010
# Epoch 12/40
# 67/67 [==============================] - ETA: 0s - loss: 1.4464 - categorical_accuracy: 0.3731
# Epoch 12: saving model to model_init_2024-01-2715_31_08.356252\model-00012-1.44640-0.37313-1.20920-0.57000.h5
# 67/67 [==============================] - 45s 674ms/step - loss: 1.4464 - categorical_accuracy: 0.3731 - val_loss: 1.2092 - val_categorical_accuracy: 0.5700 - lr: 0.0010
# Epoch 13/40
# 67/67 [==============================] - ETA: 0s - loss: 1.3031 - categorical_accuracy: 0.4129
# Epoch 13: saving model to model_init_2024-01-2715_31_08.356252\model-00013-1.30312-0.41294-1.14449-0.60000.h5
# 67/67 [==============================] - 46s 688ms/step - loss: 1.3031 - categorical_accuracy: 0.4129 - val_loss: 1.1445 - val_categorical_accuracy: 0.6000 - lr: 0.0010
# Epoch 14/40
# 67/67 [==============================] - ETA: 0s - loss: 1.3878 - categorical_accuracy: 0.4030
# Epoch 14: saving model to model_init_2024-01-2715_31_08.356252\model-00014-1.38776-0.40299-1.11314-0.62000.h5
# 67/67 [==============================] - 44s 661ms/step - loss: 1.3878 - categorical_accuracy: 0.4030 - val_loss: 1.1131 - val_categorical_accuracy: 0.6200 - lr: 0.0010
# Epoch 15/40
# 67/67 [==============================] - ETA: 0s - loss: 1.3433 - categorical_accuracy: 0.4627
# Epoch 15: saving model to model_init_2024-01-2715_31_08.356252\model-00015-1.34330-0.46269-1.29887-0.47000.h5
# 67/67 [==============================] - 44s 671ms/step - loss: 1.3433 - categorical_accuracy: 0.4627 - val_loss: 1.2989 - val_categorical_accuracy: 0.4700 - lr: 0.0010
# Epoch 16/40
# 67/67 [==============================] - ETA: 0s - loss: 1.4168 - categorical_accuracy: 0.4527
# Epoch 16: saving model to model_init_2024-01-2715_31_08.356252\model-00016-1.41678-0.45274-1.03053-0.69000.h5
# 67/67 [==============================] - 42s 641ms/step - loss: 1.4168 - categorical_accuracy: 0.4527 - val_loss: 1.0305 - val_categorical_accuracy: 0.6900 - lr: 0.0010
# Epoch 17/40
# 67/67 [==============================] - ETA: 0s - loss: 1.2638 - categorical_accuracy: 0.5075
# Epoch 17: saving model to model_init_2024-01-2715_31_08.356252\model-00017-1.26382-0.50746-1.37819-0.46000.h5
# 67/67 [==============================] - 44s 667ms/step - loss: 1.2638 - categorical_accuracy: 0.5075 - val_loss: 1.3782 - val_categorical_accuracy: 0.4600 - lr: 0.0010
# Epoch 18/40
# 67/67 [==============================] - ETA: 0s - loss: 1.2816 - categorical_accuracy: 0.5075
# Epoch 18: saving model to model_init_2024-01-2715_31_08.356252\model-00018-1.28156-0.50746-1.10187-0.56000.h5
#
# Epoch 18: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 67/67 [==============================] - 44s 666ms/step - loss: 1.2816 - categorical_accuracy: 0.5075 - val_loss: 1.1019 - val_categorical_accuracy: 0.5600 - lr: 0.0010
# Epoch 19/40
# 67/67 [==============================] - ETA: 0s - loss: 1.2604 - categorical_accuracy: 0.4925
# Epoch 19: saving model to model_init_2024-01-2715_31_08.356252\model-00019-1.26042-0.49254-1.11319-0.62000.h5
# 67/67 [==============================] - 44s 671ms/step - loss: 1.2604 - categorical_accuracy: 0.4925 - val_loss: 1.1132 - val_categorical_accuracy: 0.6200 - lr: 5.0000e-04
# Epoch 20/40
# 67/67 [==============================] - ETA: 0s - loss: 1.2259 - categorical_accuracy: 0.5124
# Epoch 20: saving model to model_init_2024-01-2715_31_08.356252\model-00020-1.22589-0.51244-1.11734-0.54000.h5
#
# Epoch 20: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 67/67 [==============================] - 44s 659ms/step - loss: 1.2259 - categorical_accuracy: 0.5124 - val_loss: 1.1173 - val_categorical_accuracy: 0.5400 - lr: 5.0000e-04
# Epoch 21/40
# 67/67 [==============================] - ETA: 0s - loss: 1.2945 - categorical_accuracy: 0.4527
# Epoch 21: saving model to model_init_2024-01-2715_31_08.356252\model-00021-1.29449-0.45274-1.04245-0.63000.h5
# 67/67 [==============================] - 42s 632ms/step - loss: 1.2945 - categorical_accuracy: 0.4527 - val_loss: 1.0425 - val_categorical_accuracy: 0.6300 - lr: 2.5000e-04
# Epoch 22/40
# 67/67 [==============================] - ETA: 0s - loss: 1.1280 - categorical_accuracy: 0.5323
# Epoch 22: saving model to model_init_2024-01-2715_31_08.356252\model-00022-1.12798-0.53234-1.02333-0.59000.h5
# 67/67 [==============================] - 44s 657ms/step - loss: 1.1280 - categorical_accuracy: 0.5323 - val_loss: 1.0233 - val_categorical_accuracy: 0.5900 - lr: 2.5000e-04
# Epoch 23/40
# 67/67 [==============================] - ETA: 0s - loss: 1.2208 - categorical_accuracy: 0.5373
# Epoch 23: saving model to model_init_2024-01-2715_31_08.356252\model-00023-1.22080-0.53731-1.04183-0.55000.h5
# 67/67 [==============================] - 44s 664ms/step - loss: 1.2208 - categorical_accuracy: 0.5373 - val_loss: 1.0418 - val_categorical_accuracy: 0.5500 - lr: 2.5000e-04
# Epoch 24/40
# 67/67 [==============================] - ETA: 0s - loss: 1.1546 - categorical_accuracy: 0.5423
# Epoch 24: saving model to model_init_2024-01-2715_31_08.356252\model-00024-1.15463-0.54229-1.02097-0.62000.h5
# 67/67 [==============================] - 43s 655ms/step - loss: 1.1546 - categorical_accuracy: 0.5423 - val_loss: 1.0210 - val_categorical_accuracy: 0.6200 - lr: 2.5000e-04
# Epoch 25/40
# 67/67 [==============================] - ETA: 0s - loss: 1.0665 - categorical_accuracy: 0.5821
# Epoch 25: saving model to model_init_2024-01-2715_31_08.356252\model-00025-1.06647-0.58209-1.05173-0.62000.h5
# 67/67 [==============================] - 46s 687ms/step - loss: 1.0665 - categorical_accuracy: 0.5821 - val_loss: 1.0517 - val_categorical_accuracy: 0.6200 - lr: 2.5000e-04
# Epoch 26/40
# 67/67 [==============================] - ETA: 0s - loss: 1.0767 - categorical_accuracy: 0.5672
# Epoch 26: saving model to model_init_2024-01-2715_31_08.356252\model-00026-1.07666-0.56716-0.93192-0.67000.h5
# 67/67 [==============================] - 43s 651ms/step - loss: 1.0767 - categorical_accuracy: 0.5672 - val_loss: 0.9319 - val_categorical_accuracy: 0.6700 - lr: 2.5000e-04
# Epoch 27/40
# 67/67 [==============================] - ETA: 0s - loss: 1.1930 - categorical_accuracy: 0.4826
# Epoch 27: saving model to model_init_2024-01-2715_31_08.356252\model-00027-1.19305-0.48259-0.99954-0.56000.h5
# 67/67 [==============================] - 43s 645ms/step - loss: 1.1930 - categorical_accuracy: 0.4826 - val_loss: 0.9995 - val_categorical_accuracy: 0.5600 - lr: 2.5000e-04
# Epoch 28/40
# 67/67 [==============================] - ETA: 0s - loss: 1.0850 - categorical_accuracy: 0.5572
# Epoch 28: saving model to model_init_2024-01-2715_31_08.356252\model-00028-1.08496-0.55721-1.04427-0.57000.h5
#
# Epoch 28: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 67/67 [==============================] - 44s 659ms/step - loss: 1.0850 - categorical_accuracy: 0.5572 - val_loss: 1.0443 - val_categorical_accuracy: 0.5700 - lr: 2.5000e-04
# Epoch 29/40
# 67/67 [==============================] - ETA: 0s - loss: 1.1035 - categorical_accuracy: 0.5672
# Epoch 29: saving model to model_init_2024-01-2715_31_08.356252\model-00029-1.10354-0.56716-0.94909-0.65000.h5
# 67/67 [==============================] - 44s 671ms/step - loss: 1.1035 - categorical_accuracy: 0.5672 - val_loss: 0.9491 - val_categorical_accuracy: 0.6500 - lr: 1.2500e-04
# Epoch 30/40
# 67/67 [==============================] - ETA: 0s - loss: 1.0778 - categorical_accuracy: 0.5821
# Epoch 30: saving model to model_init_2024-01-2715_31_08.356252\model-00030-1.07783-0.58209-1.02104-0.61000.h5
#
# Epoch 30: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 67/67 [==============================] - 44s 657ms/step - loss: 1.0778 - categorical_accuracy: 0.5821 - val_loss: 1.0210 - val_categorical_accuracy: 0.6100 - lr: 1.2500e-04
# Epoch 31/40
# 67/67 [==============================] - ETA: 0s - loss: 1.0181 - categorical_accuracy: 0.5970
# Epoch 31: saving model to model_init_2024-01-2715_31_08.356252\model-00031-1.01809-0.59701-0.93954-0.64000.h5
# 67/67 [==============================] - 45s 677ms/step - loss: 1.0181 - categorical_accuracy: 0.5970 - val_loss: 0.9395 - val_categorical_accuracy: 0.6400 - lr: 6.2500e-05
# Epoch 32/40
# 67/67 [==============================] - ETA: 0s - loss: 1.0214 - categorical_accuracy: 0.5970
# Epoch 32: saving model to model_init_2024-01-2715_31_08.356252\model-00032-1.02143-0.59701-0.92234-0.68000.h5
# 67/67 [==============================] - 45s 672ms/step - loss: 1.0214 - categorical_accuracy: 0.5970 - val_loss: 0.9223 - val_categorical_accuracy: 0.6800 - lr: 6.2500e-05
# Epoch 33/40
# 67/67 [==============================] - ETA: 0s - loss: 1.0517 - categorical_accuracy: 0.5672
# Epoch 33: saving model to model_init_2024-01-2715_31_08.356252\model-00033-1.05170-0.56716-0.96990-0.61000.h5
# 67/67 [==============================] - 43s 647ms/step - loss: 1.0517 - categorical_accuracy: 0.5672 - val_loss: 0.9699 - val_categorical_accuracy: 0.6100 - lr: 6.2500e-05
# Epoch 34/40
# 67/67 [==============================] - ETA: 0s - loss: 1.0048 - categorical_accuracy: 0.6318
# Epoch 34: saving model to model_init_2024-01-2715_31_08.356252\model-00034-1.00479-0.63184-0.90331-0.74000.h5
# 67/67 [==============================] - 43s 652ms/step - loss: 1.0048 - categorical_accuracy: 0.6318 - val_loss: 0.9033 - val_categorical_accuracy: 0.7400 - lr: 6.2500e-05
# Epoch 35/40
# 67/67 [==============================] - ETA: 0s - loss: 1.0577 - categorical_accuracy: 0.6119
# Epoch 35: saving model to model_init_2024-01-2715_31_08.356252\model-00035-1.05774-0.61194-0.91110-0.66000.h5
# 67/67 [==============================] - 45s 685ms/step - loss: 1.0577 - categorical_accuracy: 0.6119 - val_loss: 0.9111 - val_categorical_accuracy: 0.6600 - lr: 6.2500e-05
# Epoch 36/40
# 67/67 [==============================] - ETA: 0s - loss: 1.0086 - categorical_accuracy: 0.5821
# Epoch 36: saving model to model_init_2024-01-2715_31_08.356252\model-00036-1.00864-0.58209-0.92772-0.65000.h5
#
# Epoch 36: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 67/67 [==============================] - 44s 666ms/step - loss: 1.0086 - categorical_accuracy: 0.5821 - val_loss: 0.9277 - val_categorical_accuracy: 0.6500 - lr: 6.2500e-05
# Epoch 37/40
# 67/67 [==============================] - ETA: 0s - loss: 0.9456 - categorical_accuracy: 0.5920
# Epoch 37: saving model to model_init_2024-01-2715_31_08.356252\model-00037-0.94565-0.59204-0.95971-0.66000.h5
# 67/67 [==============================] - 43s 646ms/step - loss: 0.9456 - categorical_accuracy: 0.5920 - val_loss: 0.9597 - val_categorical_accuracy: 0.6600 - lr: 3.1250e-05
# Epoch 38/40
# 67/67 [==============================] - ETA: 0s - loss: 0.9659 - categorical_accuracy: 0.6020
# Epoch 38: saving model to model_init_2024-01-2715_31_08.356252\model-00038-0.96586-0.60199-0.80509-0.79000.h5
# 67/67 [==============================] - 44s 659ms/step - loss: 0.9659 - categorical_accuracy: 0.6020 - val_loss: 0.8051 - val_categorical_accuracy: 0.7900 - lr: 3.1250e-05
# Epoch 39/40
# 67/67 [==============================] - ETA: 0s - loss: 1.0427 - categorical_accuracy: 0.5473
# Epoch 39: saving model to model_init_2024-01-2715_31_08.356252\model-00039-1.04269-0.54726-0.92728-0.69000.h5
# 67/67 [==============================] - 45s 673ms/step - loss: 1.0427 - categorical_accuracy: 0.5473 - val_loss: 0.9273 - val_categorical_accuracy: 0.6900 - lr: 3.1250e-05
# Epoch 40/40
# 67/67 [==============================] - ETA: 0s - loss: 1.0928 - categorical_accuracy: 0.5721
# Epoch 40: saving model to model_init_2024-01-2715_31_08.356252\model-00040-1.09281-0.57214-0.86556-0.71000.h5
#
# Epoch 40: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 67/67 [==============================] - 43s 650ms/step - loss: 1.0928 - categorical_accuracy: 0.5721 - val_loss: 0.8656 - val_categorical_accuracy: 0.7100 - lr: 3.1250e-05

# %%
model_name = "anything.keras"
CNNRNN_Model.save(model_name)

# %%
tf.keras.models.load_model(model_name)

# %%
val_accuracy = np.mean(history.history['val_categorical_accuracy'])
print("\n%s: %.2f%%" % ('Validation Accuracy', val_accuracy*100))
# Out:
# Validation Accuracy: 54.68%

# %% [markdown]
# # **Training And Validation Loss Over Epochs**

# %%
import matplotlib.pyplot as plt

history_df = pd.DataFrame(history.history)
plt.plot(history_df.loc[:, ['loss']], "#800000", label='Training loss')
plt.plot(history_df.loc[:, ['val_loss']],"#030764", label='Validation loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')

plt.legend(loc="best")
plt.show()

# %% [markdown]
# # **Training And Validation Accuracy Over Epochs**

# %%
history_df = pd.DataFrame(history.history)

plt.plot(history_df.loc[:, ['categorical_accuracy']], "#800000", label='Training accuracy')
plt.plot(history_df.loc[:, ['val_categorical_accuracy']], "#030764", label='Validation accuracy')

plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')

plt.legend()
plt.show()

# %% [markdown]
# # **Same CNN+RNN Model with Different Image's Size (30X30)**

# %%
x = 30 # number of frames
y = 30 # image width
z = 30 # image height

CNNRNN_Model2 = Sequential()   

CNNRNN_Model2.add(TimeDistributed(Conv2D(16, (3, 3) , padding='same', activation='relu'),input_shape=(x,y,z,3)))
CNNRNN_Model2.add(TimeDistributed(BatchNormalization()))
CNNRNN_Model2.add(TimeDistributed(MaxPooling2D((2, 2))))
        
CNNRNN_Model2.add(TimeDistributed(Conv2D(32, (3, 3) , padding='same', activation='relu')))
CNNRNN_Model2.add(TimeDistributed(BatchNormalization()))
CNNRNN_Model2.add(TimeDistributed(MaxPooling2D((2, 2))))
        
CNNRNN_Model2.add(TimeDistributed(Conv2D(64, (3, 3) , padding='same', activation='relu')))
CNNRNN_Model2.add(TimeDistributed(BatchNormalization()))
CNNRNN_Model2.add(TimeDistributed(MaxPooling2D((2, 2))))
        
CNNRNN_Model2.add(TimeDistributed(Conv2D(128, (3, 3) , padding='same', activation='relu')))
CNNRNN_Model2.add(TimeDistributed(BatchNormalization()))
CNNRNN_Model2.add(TimeDistributed(MaxPooling2D((2, 2))))

# Flatten layer 

CNNRNN_Model2.add(TimeDistributed(Flatten()))

CNNRNN_Model2.add(SimpleRNN(64))
CNNRNN_Model2.add(Dropout(0.25))

# Dense layer 
CNNRNN_Model2.add(Dense(64,activation='relu'))
CNNRNN_Model2.add(Dropout(0.25))
# Softmax layer

CNNRNN_Model2.add(Dense(5, activation='softmax'))

# Adam optimiser

optimiser = optimizers.Adam(lr=0.01) #write your optimizer
CNNRNN_Model2.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
print (CNNRNN_Model2.summary())
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  time_distributed_13 (TimeD  (None, 30, 30, 30, 16)    448
#  istributed)
#
#  time_distributed_14 (TimeD  (None, 30, 30, 30, 16)    64
#  istributed)
#
#  time_distributed_15 (TimeD  (None, 30, 15, 15, 16)    0
#  istributed)
#
#  time_distributed_16 (TimeD  (None, 30, 15, 15, 32)    4640
#  istributed)
#
#  time_distributed_17 (TimeD  (None, 30, 15, 15, 32)    128
#  istributed)
#
#  time_distributed_18 (TimeD  (None, 30, 7, 7, 32)      0
#  istributed)
#
#  time_distributed_19 (TimeD  (None, 30, 7, 7, 64)      18496
#  istributed)
#
#  time_distributed_20 (TimeD  (None, 30, 7, 7, 64)      256
#  istributed)
#
#  time_distributed_21 (TimeD  (None, 30, 3, 3, 64)      0
#  istributed)
#
#  time_distributed_22 (TimeD  (None, 30, 3, 3, 128)     73856
#  istributed)
#
#  time_distributed_23 (TimeD  (None, 30, 3, 3, 128)     512
#  istributed)
#
#  time_distributed_24 (TimeD  (None, 30, 1, 1, 128)     0
#  istributed)
#
#  time_distributed_25 (TimeD  (None, 30, 128)           0
#  istributed)
#
#  simple_rnn_1 (SimpleRNN)    (None, 64)                12352
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  dense_2 (Dense)             (None, 64)                4160
#
#  dropout_3 (Dropout)         (None, 64)                0
#
#  dense_3 (Dense)             (None, 5)                 325
#
# =================================================================
# Total params: 115237 (450.14 KB)
# Trainable params: 114757 (448.27 KB)
# Non-trainable params: 480 (1.88 KB)
# _________________________________________________________________
# None

# %%
train_generator = generator_1(train_path, train_doc, batch_size)
val_generator = generator_1(val_path, val_doc, batch_size)

# %%
history1 = CNNRNN_Model2.fit(train_generator, steps_per_epoch = steps_per_epoch, epochs=40, verbose=1,
                    callbacks=callbacks_list, validation_data=val_generator, 
                    validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# Source path =  C:\Users\Rahul\Desktop\Thumbs_up_and_down_Dataset\Train ; batch size = 10
# Epoch 1/40
# 65/67 [============================>.] - ETA: 3s - loss: 1.6275 - categorical_accuracy: 0.3123Batches:  67 Index: 10
# 67/67 [==============================] - ETA: 0s - loss: 1.6235 - categorical_accuracy: 0.3137Source path =  C:\Users\Rahul\Desktop\Thumbs_up_and_down_Dataset\Val ; batch size = 10
#
# Epoch 1: saving model to model_init_2024-01-2715_31_08.356252\model-00001-1.62354-0.31373-1.73755-0.21000.h5
# 67/67 [==============================] - 129s 2s/step - loss: 1.6235 - categorical_accuracy: 0.3137 - val_loss: 1.7375 - val_categorical_accuracy: 0.2100 - lr: 0.0010
# Epoch 2/40
# 67/67 [==============================] - ETA: 0s - loss: 1.5492 - categorical_accuracy: 0.3134
# Epoch 2: saving model to model_init_2024-01-2715_31_08.356252\model-00002-1.54916-0.31343-2.05617-0.30000.h5
# 67/67 [==============================] - 51s 766ms/step - loss: 1.5492 - categorical_accuracy: 0.3134 - val_loss: 2.0562 - val_categorical_accuracy: 0.3000 - lr: 0.0010
# Epoch 3/40
# 67/67 [==============================] - ETA: 0s - loss: 1.5293 - categorical_accuracy: 0.3383
# Epoch 3: saving model to model_init_2024-01-2715_31_08.356252\model-00003-1.52930-0.33831-1.80487-0.25000.h5
#
# Epoch 3: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 67/67 [==============================] - 53s 797ms/step - loss: 1.5293 - categorical_accuracy: 0.3383 - val_loss: 1.8049 - val_categorical_accuracy: 0.2500 - lr: 0.0010
# Epoch 4/40
# 67/67 [==============================] - ETA: 0s - loss: 1.3680 - categorical_accuracy: 0.4776
# Epoch 4: saving model to model_init_2024-01-2715_31_08.356252\model-00004-1.36798-0.47761-1.86715-0.25000.h5
# 67/67 [==============================] - 54s 813ms/step - loss: 1.3680 - categorical_accuracy: 0.4776 - val_loss: 1.8672 - val_categorical_accuracy: 0.2500 - lr: 5.0000e-04
# Epoch 5/40
# 67/67 [==============================] - ETA: 0s - loss: 1.2907 - categorical_accuracy: 0.5124
# Epoch 5: saving model to model_init_2024-01-2715_31_08.356252\model-00005-1.29071-0.51244-1.71311-0.36000.h5
# 67/67 [==============================] - 46s 701ms/step - loss: 1.2907 - categorical_accuracy: 0.5124 - val_loss: 1.7131 - val_categorical_accuracy: 0.3600 - lr: 5.0000e-04
# Epoch 6/40
# 67/67 [==============================] - ETA: 0s - loss: 1.2732 - categorical_accuracy: 0.5075
# Epoch 6: saving model to model_init_2024-01-2715_31_08.356252\model-00006-1.27322-0.50746-1.50992-0.39000.h5
# 67/67 [==============================] - 37s 560ms/step - loss: 1.2732 - categorical_accuracy: 0.5075 - val_loss: 1.5099 - val_categorical_accuracy: 0.3900 - lr: 5.0000e-04
# Epoch 7/40
# 67/67 [==============================] - ETA: 0s - loss: 1.2193 - categorical_accuracy: 0.4726
# Epoch 7: saving model to model_init_2024-01-2715_31_08.356252\model-00007-1.21933-0.47264-1.24251-0.45000.h5
# 67/67 [==============================] - 41s 622ms/step - loss: 1.2193 - categorical_accuracy: 0.4726 - val_loss: 1.2425 - val_categorical_accuracy: 0.4500 - lr: 5.0000e-04
# Epoch 8/40
# 67/67 [==============================] - ETA: 0s - loss: 1.1573 - categorical_accuracy: 0.5323
# Epoch 8: saving model to model_init_2024-01-2715_31_08.356252\model-00008-1.15730-0.53234-1.13268-0.52000.h5
# 67/67 [==============================] - 36s 553ms/step - loss: 1.1573 - categorical_accuracy: 0.5323 - val_loss: 1.1327 - val_categorical_accuracy: 0.5200 - lr: 5.0000e-04
# Epoch 9/40
# 67/67 [==============================] - ETA: 0s - loss: 1.2464 - categorical_accuracy: 0.5025
# Epoch 9: saving model to model_init_2024-01-2715_31_08.356252\model-00009-1.24644-0.50249-1.18632-0.51000.h5
# 67/67 [==============================] - 34s 511ms/step - loss: 1.2464 - categorical_accuracy: 0.5025 - val_loss: 1.1863 - val_categorical_accuracy: 0.5100 - lr: 5.0000e-04
# Epoch 10/40
# 67/67 [==============================] - ETA: 0s - loss: 1.0702 - categorical_accuracy: 0.6020
# Epoch 10: saving model to model_init_2024-01-2715_31_08.356252\model-00010-1.07018-0.60199-1.17053-0.56000.h5
#
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 67/67 [==============================] - 34s 522ms/step - loss: 1.0702 - categorical_accuracy: 0.6020 - val_loss: 1.1705 - val_categorical_accuracy: 0.5600 - lr: 5.0000e-04
# Epoch 11/40
# 67/67 [==============================] - ETA: 0s - loss: 1.0010 - categorical_accuracy: 0.6368
# Epoch 11: saving model to model_init_2024-01-2715_31_08.356252\model-00011-1.00104-0.63682-1.08129-0.57000.h5
# 67/67 [==============================] - 37s 558ms/step - loss: 1.0010 - categorical_accuracy: 0.6368 - val_loss: 1.0813 - val_categorical_accuracy: 0.5700 - lr: 2.5000e-04
# Epoch 12/40
# 67/67 [==============================] - ETA: 0s - loss: 0.9399 - categorical_accuracy: 0.6617
# Epoch 12: saving model to model_init_2024-01-2715_31_08.356252\model-00012-0.93989-0.66169-1.08030-0.57000.h5
# 67/67 [==============================] - 35s 536ms/step - loss: 0.9399 - categorical_accuracy: 0.6617 - val_loss: 1.0803 - val_categorical_accuracy: 0.5700 - lr: 2.5000e-04
# Epoch 13/40
# 67/67 [==============================] - ETA: 0s - loss: 0.9950 - categorical_accuracy: 0.6219
# Epoch 13: saving model to model_init_2024-01-2715_31_08.356252\model-00013-0.99501-0.62189-1.09211-0.55000.h5
# 67/67 [==============================] - 34s 511ms/step - loss: 0.9950 - categorical_accuracy: 0.6219 - val_loss: 1.0921 - val_categorical_accuracy: 0.5500 - lr: 2.5000e-04
# Epoch 14/40
# 67/67 [==============================] - ETA: 0s - loss: 0.8678 - categorical_accuracy: 0.6965
# Epoch 14: saving model to model_init_2024-01-2715_31_08.356252\model-00014-0.86781-0.69652-1.03261-0.59000.h5
# 67/67 [==============================] - 35s 535ms/step - loss: 0.8678 - categorical_accuracy: 0.6965 - val_loss: 1.0326 - val_categorical_accuracy: 0.5900 - lr: 2.5000e-04
# Epoch 15/40
# 67/67 [==============================] - ETA: 0s - loss: 0.8017 - categorical_accuracy: 0.6866
# Epoch 15: saving model to model_init_2024-01-2715_31_08.356252\model-00015-0.80166-0.68657-1.22232-0.48000.h5
# 67/67 [==============================] - 33s 502ms/step - loss: 0.8017 - categorical_accuracy: 0.6866 - val_loss: 1.2223 - val_categorical_accuracy: 0.4800 - lr: 2.5000e-04
# Epoch 16/40
# 67/67 [==============================] - ETA: 0s - loss: 0.6473 - categorical_accuracy: 0.7910
# Epoch 16: saving model to model_init_2024-01-2715_31_08.356252\model-00016-0.64733-0.79104-1.05590-0.55000.h5
#
# Epoch 16: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 67/67 [==============================] - 34s 513ms/step - loss: 0.6473 - categorical_accuracy: 0.7910 - val_loss: 1.0559 - val_categorical_accuracy: 0.5500 - lr: 2.5000e-04
# Epoch 17/40
# 67/67 [==============================] - ETA: 0s - loss: 0.7302 - categorical_accuracy: 0.7363
# Epoch 17: saving model to model_init_2024-01-2715_31_08.356252\model-00017-0.73024-0.73632-1.05613-0.54000.h5
# 67/67 [==============================] - 34s 521ms/step - loss: 0.7302 - categorical_accuracy: 0.7363 - val_loss: 1.0561 - val_categorical_accuracy: 0.5400 - lr: 1.2500e-04
# Epoch 18/40
# 67/67 [==============================] - ETA: 0s - loss: 0.7825 - categorical_accuracy: 0.7164
# Epoch 18: saving model to model_init_2024-01-2715_31_08.356252\model-00018-0.78248-0.71642-1.12515-0.61000.h5
#
# Epoch 18: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 67/67 [==============================] - 39s 593ms/step - loss: 0.7825 - categorical_accuracy: 0.7164 - val_loss: 1.1251 - val_categorical_accuracy: 0.6100 - lr: 1.2500e-04
# Epoch 19/40
# 67/67 [==============================] - ETA: 0s - loss: 0.5515 - categorical_accuracy: 0.8259
# Epoch 19: saving model to model_init_2024-01-2715_31_08.356252\model-00019-0.55146-0.82587-1.02568-0.56000.h5
# 67/67 [==============================] - 32s 490ms/step - loss: 0.5515 - categorical_accuracy: 0.8259 - val_loss: 1.0257 - val_categorical_accuracy: 0.5600 - lr: 6.2500e-05
# Epoch 20/40
# 67/67 [==============================] - ETA: 0s - loss: 0.5850 - categorical_accuracy: 0.8010
# Epoch 20: saving model to model_init_2024-01-2715_31_08.356252\model-00020-0.58495-0.80100-1.10762-0.54000.h5
# 67/67 [==============================] - 40s 610ms/step - loss: 0.5850 - categorical_accuracy: 0.8010 - val_loss: 1.1076 - val_categorical_accuracy: 0.5400 - lr: 6.2500e-05
# Epoch 21/40
# 67/67 [==============================] - ETA: 0s - loss: 0.5910 - categorical_accuracy: 0.8209
# Epoch 21: saving model to model_init_2024-01-2715_31_08.356252\model-00021-0.59102-0.82090-1.06917-0.55000.h5
#
# Epoch 21: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 67/67 [==============================] - 32s 487ms/step - loss: 0.5910 - categorical_accuracy: 0.8209 - val_loss: 1.0692 - val_categorical_accuracy: 0.5500 - lr: 6.2500e-05
# Epoch 22/40
# 67/67 [==============================] - ETA: 0s - loss: 0.5294 - categorical_accuracy: 0.8060
# Epoch 22: saving model to model_init_2024-01-2715_31_08.356252\model-00022-0.52944-0.80597-1.14526-0.55000.h5
# 67/67 [==============================] - 50s 764ms/step - loss: 0.5294 - categorical_accuracy: 0.8060 - val_loss: 1.1453 - val_categorical_accuracy: 0.5500 - lr: 3.1250e-05
# Epoch 23/40
# 67/67 [==============================] - ETA: 0s - loss: 0.4631 - categorical_accuracy: 0.8856
# Epoch 23: saving model to model_init_2024-01-2715_31_08.356252\model-00023-0.46313-0.88557-0.99019-0.62000.h5
# 67/67 [==============================] - 44s 662ms/step - loss: 0.4631 - categorical_accuracy: 0.8856 - val_loss: 0.9902 - val_categorical_accuracy: 0.6200 - lr: 3.1250e-05
# Epoch 24/40
# 67/67 [==============================] - ETA: 0s - loss: 0.4643 - categorical_accuracy: 0.8856
# Epoch 24: saving model to model_init_2024-01-2715_31_08.356252\model-00024-0.46433-0.88557-1.06479-0.54000.h5
# 67/67 [==============================] - 50s 752ms/step - loss: 0.4643 - categorical_accuracy: 0.8856 - val_loss: 1.0648 - val_categorical_accuracy: 0.5400 - lr: 3.1250e-05
# Epoch 25/40
# 67/67 [==============================] - ETA: 0s - loss: 0.4409 - categorical_accuracy: 0.8706
# Epoch 25: saving model to model_init_2024-01-2715_31_08.356252\model-00025-0.44089-0.87065-0.96415-0.64000.h5
# 67/67 [==============================] - 44s 665ms/step - loss: 0.4409 - categorical_accuracy: 0.8706 - val_loss: 0.9642 - val_categorical_accuracy: 0.6400 - lr: 3.1250e-05
# Epoch 26/40
# 67/67 [==============================] - ETA: 0s - loss: 0.4913 - categorical_accuracy: 0.8259
# Epoch 26: saving model to model_init_2024-01-2715_31_08.356252\model-00026-0.49131-0.82587-1.16452-0.52000.h5
# 67/67 [==============================] - 54s 824ms/step - loss: 0.4913 - categorical_accuracy: 0.8259 - val_loss: 1.1645 - val_categorical_accuracy: 0.5200 - lr: 3.1250e-05
# Epoch 27/40
# 67/67 [==============================] - ETA: 0s - loss: 0.4759 - categorical_accuracy: 0.8458
# Epoch 27: saving model to model_init_2024-01-2715_31_08.356252\model-00027-0.47595-0.84577-1.09759-0.57000.h5
#
# Epoch 27: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 67/67 [==============================] - 45s 684ms/step - loss: 0.4759 - categorical_accuracy: 0.8458 - val_loss: 1.0976 - val_categorical_accuracy: 0.5700 - lr: 3.1250e-05
# Epoch 28/40
# 67/67 [==============================] - ETA: 0s - loss: 0.5156 - categorical_accuracy: 0.8010
# Epoch 28: saving model to model_init_2024-01-2715_31_08.356252\model-00028-0.51556-0.80100-1.09254-0.62000.h5
# 67/67 [==============================] - 42s 640ms/step - loss: 0.5156 - categorical_accuracy: 0.8010 - val_loss: 1.0925 - val_categorical_accuracy: 0.6200 - lr: 1.5625e-05
# Epoch 29/40
# 67/67 [==============================] - ETA: 0s - loss: 0.4431 - categorical_accuracy: 0.8756
# Epoch 29: saving model to model_init_2024-01-2715_31_08.356252\model-00029-0.44312-0.87562-1.09762-0.59000.h5
#
# Epoch 29: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 67/67 [==============================] - 48s 724ms/step - loss: 0.4431 - categorical_accuracy: 0.8756 - val_loss: 1.0976 - val_categorical_accuracy: 0.5900 - lr: 1.5625e-05
# Epoch 30/40
# 67/67 [==============================] - ETA: 0s - loss: 0.4902 - categorical_accuracy: 0.8607
# Epoch 30: saving model to model_init_2024-01-2715_31_08.356252\model-00030-0.49019-0.86070-1.10510-0.55000.h5
# 67/67 [==============================] - 49s 735ms/step - loss: 0.4902 - categorical_accuracy: 0.8607 - val_loss: 1.1051 - val_categorical_accuracy: 0.5500 - lr: 7.8125e-06
# Epoch 31/40
# 67/67 [==============================] - ETA: 0s - loss: 0.4067 - categorical_accuracy: 0.8657
# Epoch 31: saving model to model_init_2024-01-2715_31_08.356252\model-00031-0.40665-0.86567-1.08395-0.57000.h5
#
# Epoch 31: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 67/67 [==============================] - 40s 607ms/step - loss: 0.4067 - categorical_accuracy: 0.8657 - val_loss: 1.0840 - val_categorical_accuracy: 0.5700 - lr: 7.8125e-06
# Epoch 32/40
# 67/67 [==============================] - ETA: 0s - loss: 0.4928 - categorical_accuracy: 0.8458
# Epoch 32: saving model to model_init_2024-01-2715_31_08.356252\model-00032-0.49280-0.84577-1.10193-0.58000.h5
# 67/67 [==============================] - 39s 598ms/step - loss: 0.4928 - categorical_accuracy: 0.8458 - val_loss: 1.1019 - val_categorical_accuracy: 0.5800 - lr: 3.9063e-06
# Epoch 33/40
# 67/67 [==============================] - ETA: 0s - loss: 0.5237 - categorical_accuracy: 0.8408
# Epoch 33: saving model to model_init_2024-01-2715_31_08.356252\model-00033-0.52365-0.84080-1.14295-0.56000.h5
#
# Epoch 33: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# 67/67 [==============================] - 27s 407ms/step - loss: 0.5237 - categorical_accuracy: 0.8408 - val_loss: 1.1430 - val_categorical_accuracy: 0.5600 - lr: 3.9063e-06
# Epoch 34/40
# 67/67 [==============================] - ETA: 0s - loss: 0.4613 - categorical_accuracy: 0.8507
# Epoch 34: saving model to model_init_2024-01-2715_31_08.356252\model-00034-0.46132-0.85075-1.11114-0.54000.h5
# 67/67 [==============================] - 41s 625ms/step - loss: 0.4613 - categorical_accuracy: 0.8507 - val_loss: 1.1111 - val_categorical_accuracy: 0.5400 - lr: 1.9531e-06
# Epoch 35/40
# 67/67 [==============================] - ETA: 0s - loss: 0.4236 - categorical_accuracy: 0.8756
# Epoch 35: saving model to model_init_2024-01-2715_31_08.356252\model-00035-0.42364-0.87562-1.00178-0.61000.h5
#
# Epoch 35: ReduceLROnPlateau reducing learning rate to 9.765625463842298e-07.
# 67/67 [==============================] - 33s 494ms/step - loss: 0.4236 - categorical_accuracy: 0.8756 - val_loss: 1.0018 - val_categorical_accuracy: 0.6100 - lr: 1.9531e-06
# Epoch 36/40
# 67/67 [==============================] - ETA: 0s - loss: 0.4294 - categorical_accuracy: 0.8657
# Epoch 36: saving model to model_init_2024-01-2715_31_08.356252\model-00036-0.42940-0.86567-1.18708-0.55000.h5
# 67/67 [==============================] - 39s 592ms/step - loss: 0.4294 - categorical_accuracy: 0.8657 - val_loss: 1.1871 - val_categorical_accuracy: 0.5500 - lr: 9.7656e-07
# Epoch 37/40
# 67/67 [==============================] - ETA: 0s - loss: 0.4200 - categorical_accuracy: 0.8756
# Epoch 37: saving model to model_init_2024-01-2715_31_08.356252\model-00037-0.42004-0.87562-0.99182-0.61000.h5
#
# Epoch 37: ReduceLROnPlateau reducing learning rate to 4.882812731921149e-07.
# 67/67 [==============================] - 33s 498ms/step - loss: 0.4200 - categorical_accuracy: 0.8756 - val_loss: 0.9918 - val_categorical_accuracy: 0.6100 - lr: 9.7656e-07
# Epoch 38/40
# 67/67 [==============================] - ETA: 0s - loss: 0.3954 - categorical_accuracy: 0.8955
# Epoch 38: saving model to model_init_2024-01-2715_31_08.356252\model-00038-0.39536-0.89552-1.05886-0.62000.h5
# 67/67 [==============================] - 35s 523ms/step - loss: 0.3954 - categorical_accuracy: 0.8955 - val_loss: 1.0589 - val_categorical_accuracy: 0.6200 - lr: 4.8828e-07
# Epoch 39/40
# 67/67 [==============================] - ETA: 0s - loss: 0.4597 - categorical_accuracy: 0.8408
# Epoch 39: saving model to model_init_2024-01-2715_31_08.356252\model-00039-0.45969-0.84080-1.09715-0.57000.h5
#
# Epoch 39: ReduceLROnPlateau reducing learning rate to 2.4414063659605745e-07.
# 67/67 [==============================] - 39s 595ms/step - loss: 0.4597 - categorical_accuracy: 0.8408 - val_loss: 1.0971 - val_categorical_accuracy: 0.5700 - lr: 4.8828e-07
# Epoch 40/40
# 67/67 [==============================] - ETA: 0s - loss: 0.5097 - categorical_accuracy: 0.8358
# Epoch 40: saving model to model_init_2024-01-2715_31_08.356252\model-00040-0.50975-0.83582-1.17474-0.54000.h5
# 67/67 [==============================] - 28s 429ms/step - loss: 0.5097 - categorical_accuracy: 0.8358 - val_loss: 1.1747 - val_categorical_accuracy: 0.5400 - lr: 2.4414e-07

# %%
val_accuracy = np.mean(history1.history['val_categorical_accuracy'])
print("\n%s: %.2f%%" % ('Validation Accuracy', val_accuracy*100))
# Out:
# Validation Accuracy: 52.15%

# %% [markdown]
# # **Training And Validation Loss Over Epochs (Image's Size 30X30)**

# %%
history_df = pd.DataFrame(history1.history)
plt.plot(history_df.loc[:, ['loss']], "#800000", label='Training loss')
plt.plot(history_df.loc[:, ['val_loss']],"#030764", label='Validation loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')

plt.legend(loc="best")
plt.show()

# %% [markdown]
# # **Training And Validation Accuracy Over Epochs (Image's Size 30X30)**

# %%
history_df = pd.DataFrame(history1.history)

plt.plot(history_df.loc[:, ['categorical_accuracy']], "#800000", label='Training accuracy')
plt.plot(history_df.loc[:, ['val_categorical_accuracy']], "#030764", label='Validation accuracy')

plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')

plt.legend()
plt.show()

# %%
model_name1 = "anything2.keras"
CNNRNN_Model2.save(model_name1)

# %%
tf.keras.models.load_model(model_name1)
